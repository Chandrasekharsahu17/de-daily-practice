# %% [markdown]
# # Day 02 — Jun 02 2026 (Tuesday)
# ## Topic: Dictionaries and Sets
#
# ---
# **Rule:** Attempt 15 min before Googling. Write what you tried even if wrong.

# %% [markdown]
# ## CONCEPT RECAP — Read this first
#
# > Run this example. Understand each line. Then close it and write your own code.

# %%
# ─── CONCEPT EXAMPLE ───────────────────────────────

# Grouping by key
orders = [{'id':1,'status':'completed'},{'id':2,'status':'pending'},{'id':3,'status':'completed'}]
grouped = {}
for o in orders:
    s = o['status']
    if s not in grouped: grouped[s] = []
    grouped[s].append(o)  # append FULL dict
# Result: {'completed':[{id:1},{id:3}], 'pending':[{id:2}]}

# Set operations
yesterday = {101, 102, 103}
today     = {103, 104, 105}
new   = today - yesterday     # {104,105}
lost  = yesterday - today     # {101,102}
kept  = yesterday & today     # {103}

# %% [markdown]
# ---
# ## Q1
#
# > Given a list of order dicts, write group_by_status(orders) that returns {'completed':[...],'pending':[...]}. Append the FULL dict, not just the id.

# %%
# YOUR CODE:
# Attempt before Googling
# If stuck: write what you tried and WHY it failed

# %% [markdown]
# ---
# ## Q2
#
# > Given two lists of customer_ids (yesterday and today), find: new customers, lost customers, retained. Use & and - operators on sets.

# %%
# YOUR CODE:

# %% [markdown]
# ---
# ## Reflect
#
# **What was hardest?**
# `YOUR ANSWER:`
#
# **What did you learn?**
# `YOUR ANSWER:`
#
# **Confidence 1-10:**
# `YOUR ANSWER:`
#
# **If stuck — what did you try first?**
# `YOUR ANSWER:`
