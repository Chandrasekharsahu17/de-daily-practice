# %% [markdown]
# # Day 35 — Jul 14 2026 (Tuesday)
# ## Topic: Performance and Memory
#
# ---
# **Rule:** Attempt 15 min before Googling. Write what you tried even if wrong.

# %% [markdown]
# ## CONCEPT RECAP — Read this first
#
# > Run this example. Understand each line. Then close it and write your own code.

# %%
# ─── CONCEPT EXAMPLE ───────────────────────────────

import pandas as pd

# Check memory
df = pd.DataFrame({'dept':['IT','HR','IT']*1000,'salary':[85000,72000,92000]*1000})
print(df.memory_usage(deep=True).sum()/1024**2, 'MB')

# Optimize
df['dept'] = df['dept'].astype('category')  # saves memory for repeated strings
df['salary'] = df['salary'].astype('int32')  # int64->int32
print(df.memory_usage(deep=True).sum()/1024**2, 'MB')

# %% [markdown]
# ---
# ## Q1
#
# > Create 100k row DataFrame. Measure memory. Optimize all columns. Report % reduction.

# %%
# YOUR CODE:
# Attempt before Googling
# If stuck: write what you tried and WHY it failed

# %% [markdown]
# ---
# ## Q2
#
# > Compare time: add annual column to 100k rows via iterrows, apply, vectorized. Print speedup. Comment: which to use in production.

# %%
# YOUR CODE:

# %% [markdown]
# ---
# ## Reflect
#
# **What was hardest?**
# `YOUR ANSWER:`
#
# **What did you learn?**
# `YOUR ANSWER:`
#
# **Confidence 1-10:**
# `YOUR ANSWER:`
#
# **If stuck — what did you try first?**
# `YOUR ANSWER:`
