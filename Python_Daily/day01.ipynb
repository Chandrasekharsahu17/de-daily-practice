# %% [markdown]
# # Day 01 — Jun 01 2026 (Monday)
# ## Topic: Lists and Loops
#
# ---
# **Rule:** Attempt 15 min before Googling. Write what you tried even if wrong.

# %% [markdown]
# ## CONCEPT RECAP — Read this first
#
# > Run this example. Understand each line. Then close it and write your own code.

# %%
# ─── CONCEPT EXAMPLE ───────────────────────────────

rows = [
    {'id':1,'name':'Raj','salary':85000},
    {'id':2,'name':'Priya','salary':None}
]

# Loop through rows
for row in rows:
    if row['salary'] is not None:
        print(row['name'], row['salary'] * 12)

# Clean: remove None salaries
clean = [r for r in rows if r['salary'] is not None]

# %% [markdown]
# ---
# ## Q1
#
# > Given a list of 8 salaries, write a function that returns only salaries above a given threshold. Call it twice with different thresholds.

# %%
# YOUR CODE:
# Attempt before Googling
# If stuck: write what you tried and WHY it failed

# %% [markdown]
# ---
# ## Q2
#
# > Write a function clean_names(names) that takes a LIST of names, strips whitespace, converts to title case, and removes duplicates. Test with messy data.

# %%
# YOUR CODE:

# %% [markdown]
# ---
# ## Reflect
#
# **What was hardest?**
# `YOUR ANSWER:`
#
# **What did you learn?**
# `YOUR ANSWER:`
#
# **Confidence 1-10:**
# `YOUR ANSWER:`
#
# **If stuck — what did you try first?**
# `YOUR ANSWER:`
