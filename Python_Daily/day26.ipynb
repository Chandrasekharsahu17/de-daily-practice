# %% [markdown]
# # Day 26 — Jul 01 2026 (Wednesday)
# ## Topic: APIs and JSON
#
# ---
# **Rule:** Attempt 15 min before Googling. Write what you tried even if wrong.

# %% [markdown]
# ## CONCEPT RECAP — Read this first
#
# > Run this example. Understand each line. Then close it and write your own code.

# %%
# ─── CONCEPT EXAMPLE ───────────────────────────────

import requests

# GET request
try:
    r = requests.get('https://jsonplaceholder.typicode.com/posts', timeout=5)
    r.raise_for_status()  # error for 4xx/5xx
    data = r.json()
    print(f'Got {len(data)} posts')
except requests.exceptions.Timeout:
    print('Request timed out')
except requests.exceptions.HTTPError as e:
    print(f'HTTP error: {e}')

# Safe nested access
nested = {'user':{'name':'Raj','address':{'city':'Mumbai'}}}
city = nested.get('user',{}).get('address',{}).get('city','Unknown')
# No KeyError even if key missing

# %% [markdown]
# ---
# ## Q1
#
# > Fetch from https://jsonplaceholder.typicode.com/posts: load into DataFrame, find posts per user, avg title length, longest post. Save to posts.csv.

# %%
# YOUR CODE:
# Attempt before Googling
# If stuck: write what you tried and WHY it failed

# %% [markdown]
# ---
# ## Q2
#
# > Write safe_json_extract(data, path) where path=['user','address','city']. Navigate nested JSON safely. Test with complete dict, partial dict, empty dict.

# %%
# YOUR CODE:

# %% [markdown]
# ---
# ## Reflect
#
# **What was hardest?**
# `YOUR ANSWER:`
#
# **What did you learn?**
# `YOUR ANSWER:`
#
# **Confidence 1-10:**
# `YOUR ANSWER:`
#
# **If stuck — what did you try first?**
# `YOUR ANSWER:`
