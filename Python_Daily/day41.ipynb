# %% [markdown]
# # Day 41 — Jul 22 2026 (Wednesday)
# ## Topic: Real World Scenario 2
#
# ---
# **Rule:** Attempt 15 min before Googling. Write what you tried even if wrong.

# %% [markdown]
# ## CONCEPT RECAP — Read this first
#
# > Run this example. Understand each line. Then close it and write your own code.

# %%
# ─── CONCEPT EXAMPLE ───────────────────────────────

# SCD Type 2: keeping history of changes
# Customer moves city: keep old record + add new
# effective_start, effective_end, is_current columns

# %% [markdown]
# ---
# ## Q1
#
# > Detect changes between yesterday and today customer snapshots: new customers, deleted, city/tier changed. Output change_report dict.

# %%
# YOUR CODE:
# Attempt before Googling
# If stuck: write what you tried and WHY it failed

# %% [markdown]
# ---
# ## Q2
#
# > Implement SCD Type 2 for customer city changes: add effective_start, effective_end, is_current. Test with 2 customers whose city changed.

# %%
# YOUR CODE:

# %% [markdown]
# ---
# ## Reflect
#
# **What was hardest?**
# `YOUR ANSWER:`
#
# **What did you learn?**
# `YOUR ANSWER:`
#
# **Confidence 1-10:**
# `YOUR ANSWER:`
#
# **If stuck — what did you try first?**
# `YOUR ANSWER:`
