# %% [markdown]
# # Day 40 — Jul 21 2026 (Tuesday)
# ## Topic: Mixed Review
#
# ---
# **Rule:** Attempt 15 min before Googling. Write what you tried even if wrong.

# %% [markdown]
# ## CONCEPT RECAP — Read this first
#
# > Run this example. Understand each line. Then close it and write your own code.

# %%
# ─── CONCEPT EXAMPLE ───────────────────────────────

# Day 40 - pick 2 weakest days from 1-39
# No new concepts
# Redo those questions from scratch

# %% [markdown]
# ---
# ## Q1
#
# > Write your own hard groupby/aggregation question. Solve it with real-looking data.

# %%
# YOUR CODE:
# Attempt before Googling
# If stuck: write what you tried and WHY it failed

# %% [markdown]
# ---
# ## Q2
#
# > Write your own hard exception handling in pipeline question. Solve with proper try/except/logging.

# %%
# YOUR CODE:

# %% [markdown]
# ---
# ## Reflect
#
# **What was hardest?**
# `YOUR ANSWER:`
#
# **What did you learn?**
# `YOUR ANSWER:`
#
# **Confidence 1-10:**
# `YOUR ANSWER:`
#
# **If stuck — what did you try first?**
# `YOUR ANSWER:`
