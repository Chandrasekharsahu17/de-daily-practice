# %% [markdown]
# # Day 43 — Jul 24 2026 (Friday)
# ## Topic: Validation Patterns
#
# ---
# **Rule:** Attempt 15 min before Googling. Write what you tried even if wrong.

# %% [markdown]
# ## CONCEPT RECAP — Read this first
#
# > Run this example. Understand each line. Then close it and write your own code.

# %%
# ─── CONCEPT EXAMPLE ───────────────────────────────

# Production validation = define rules, check data quality automatically
# CRITICAL: halt pipeline
# WARNING: log and continue
# INFO: log only

# %% [markdown]
# ---
# ## Q1
#
# > Build complete validation framework with 5 rules. Test on clean and messy DataFrames. Report: total/passed/failed per severity.

# %%
# YOUR CODE:
# Attempt before Googling
# If stuck: write what you tried and WHY it failed

# %% [markdown]
# ---
# ## Q2
#
# > Add auto-fix: null required=drop row, out of range=clip, not in allowed=Unknown. Return (fixed_df, fix_report) showing what changed.

# %%
# YOUR CODE:

# %% [markdown]
# ---
# ## Reflect
#
# **What was hardest?**
# `YOUR ANSWER:`
#
# **What did you learn?**
# `YOUR ANSWER:`
#
# **Confidence 1-10:**
# `YOUR ANSWER:`
#
# **If stuck — what did you try first?**
# `YOUR ANSWER:`
