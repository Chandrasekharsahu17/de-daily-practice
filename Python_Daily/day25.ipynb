# %% [markdown]
# # Day 25 — Jun 30 2026 (Tuesday)
# ## Topic: Generators
#
# ---
# **Rule:** Attempt 15 min before Googling. Write what you tried even if wrong.

# %% [markdown]
# ## CONCEPT RECAP — Read this first
#
# > Run this example. Understand each line. Then close it and write your own code.

# %%
# ─── CONCEPT EXAMPLE ───────────────────────────────

# yield: give value AND pause, resume later

def read_chunks(filepath, chunk_size=1000):
    chunk = []
    with open(filepath) as f:
        for line in f:
            chunk.append(line.strip())
            if len(chunk) == chunk_size:
                yield chunk     # give chunk, pause
                chunk = []      # reset
    if chunk:
        yield chunk  # remaining rows

# Process large file without loading all into RAM
for chunk in read_chunks('huge.csv'):
    process(chunk)  # only 1000 rows at a time

# list vs generator memory
big_list = [x**2 for x in range(1000000)]  # all in RAM
gen = (x**2 for x in range(1000000))       # one at a time

# %% [markdown]
# ---
# ## Q1
#
# > Write read_in_chunks(filepath, chunk_size=100) generator: yields chunks as list of strings. Simulate 500-row file. Print chunk number and size.

# %%
# YOUR CODE:
# Attempt before Googling
# If stuck: write what you tried and WHY it failed

# %% [markdown]
# ---
# ## Q2
#
# > Write batch_insert_generator(records, batch_size=100): yields batches. Use to insert 500 records into SQLite 100 at a time. Compare time vs inserting all at once.

# %%
# YOUR CODE:

# %% [markdown]
# ---
# ## Reflect
#
# **What was hardest?**
# `YOUR ANSWER:`
#
# **What did you learn?**
# `YOUR ANSWER:`
#
# **Confidence 1-10:**
# `YOUR ANSWER:`
#
# **If stuck — what did you try first?**
# `YOUR ANSWER:`
