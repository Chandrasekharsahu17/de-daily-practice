# %% [markdown]
# # Day 13 — Jun 15 2026 (Monday)
# ## Topic: Pandas Basics
#
# ---
# **Rule:** Attempt 15 min before Googling. Write what you tried even if wrong.

# %% [markdown]
# ## CONCEPT RECAP — Read this first
#
# > Run this example. Understand each line. Then close it and write your own code.

# %%
# ─── CONCEPT EXAMPLE ───────────────────────────────

import pandas as pd

df = pd.DataFrame([
    {'emp_id':1,'name':'Raj','dept':'IT','salary':85000},
    {'emp_id':2,'name':'Priya','dept':'HR','salary':72000},
    {'emp_id':3,'name':'Amit','dept':'IT','salary':92000},
])

# Always explore first
df.shape            # (3, 4)
df.dtypes           # column types
df.info()           # nulls + types
df.describe()       # stats
df.isnull().sum()   # null count per col
df.head(2)          # first 2 rows

# %% [markdown]
# ---
# ## Q1
#
# > Create employee DataFrame (8 rows: emp_id, name, dept, salary, hire_year, city).
# Make 2 same dept. Make 1 salary=None.
# Run shape, dtypes, info(), describe(), value_counts('dept').
# Write a comment for each output explaining what it tells you.

# %%
# YOUR CODE:
# Attempt before Googling
# If stuck: write what you tried and WHY it failed

# %% [markdown]
# ---
# ## Q2
#
# > Product price Series: products={'Laptop':75000,'Phone':25000,'Tablet':40000,'Watch':8000}
# 1. Filter above 20000
# 2. Apply 10% discount
# 3. Add Monitor:28000
# 4. What % does each product contribute to total value?

# %%
# YOUR CODE:

# %% [markdown]
# ---
# ## Reflect
#
# **What was hardest?**
# `YOUR ANSWER:`
#
# **What did you learn?**
# `YOUR ANSWER:`
#
# **Confidence 1-10:**
# `YOUR ANSWER:`
#
# **If stuck — what did you try first?**
# `YOUR ANSWER:`
