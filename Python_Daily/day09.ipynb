# %% [markdown]
# # Day 09 — Jun 10 2026 (Wednesday)
# ## Topic: Date and Time
#
# ---
# **Rule:** Attempt 15 min before Googling. Write what you tried even if wrong.

# %% [markdown]
# ## CONCEPT RECAP — Read this first
#
# > Run this example. Understand each line. Then close it and write your own code.

# %%
# ─── CONCEPT EXAMPLE ───────────────────────────────

from datetime import datetime, date, timedelta

today = date.today()     # 2026-06-05
now   = datetime.now()   # 2026-06-05 14:30:00

# Parse string to datetime
d = datetime.strptime('15/03/2024', '%d/%m/%Y')

# Format datetime to string
s = d.strftime('%Y-%m-%d')  # '2024-03-15'

# Arithmetic
tomorrow  = today + timedelta(days=1)
last_week = today - timedelta(days=7)

# Difference
diff = date(2024,3,15) - date(2024,1,1)
diff.days   # 74

# Extract parts
today.year    # 2026
today.month   # 6

# %% [markdown]
# ---
# ## Q1
#
# > Parse these into YYYY-MM-DD:
# dates = ['15/03/2024','March 15 2024','2024.03.15','15-Mar-24']
# For each try to parse. If fails, print 'bad date'. Print all successfully parsed.

# %%
# YOUR CODE:
# Attempt before Googling
# If stuck: write what you tried and WHY it failed

# %% [markdown]
# ---
# ## Q2
#
# > Write pipeline_overdue(last_run_str, frequency):
# last_run_str='YYYY-MM-DD', frequency='daily' or 'weekly'
# Return {'should_run':True/False,'days_since_last_run':N,'overdue_by':N}

# %%
# YOUR CODE:

# %% [markdown]
# ---
# ## Reflect
#
# **What was hardest?**
# `YOUR ANSWER:`
#
# **What did you learn?**
# `YOUR ANSWER:`
#
# **Confidence 1-10:**
# `YOUR ANSWER:`
#
# **If stuck — what did you try first?**
# `YOUR ANSWER:`
