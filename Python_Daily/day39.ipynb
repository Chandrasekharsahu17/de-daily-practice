# %% [markdown]
# # Day 39 — Jul 20 2026 (Monday)
# ## Topic: Interview Prep
#
# ---
# **Rule:** Attempt 15 min before Googling. Write what you tried even if wrong.

# %% [markdown]
# ## CONCEPT RECAP — Read this first
#
# > Run this example. Understand each line. Then close it and write your own code.

# %%
# ─── CONCEPT EXAMPLE ───────────────────────────────

# Most common DE interview Python questions:
# 1. Write an ETL pipeline
# 2. Clean messy data
# 3. Handle errors in production
# 4. Process large file efficiently
# 5. OOP pipeline class

# %% [markdown]
# ---
# ## Q1
#
# > Interviewer question: Write a function that reads transactions CSV, removes duplicates, calculates revenue per category, loads to SQLite. Handle all errors. No hints.

# %%
# YOUR CODE:
# Attempt before Googling
# If stuck: write what you tried and WHY it failed

# %% [markdown]
# ---
# ## Q2
#
# > Interviewer question: You have a CSV with 1 billion rows. How do you process it without running out of memory? Write the code demonstrating chunked processing.

# %%
# YOUR CODE:

# %% [markdown]
# ---
# ## Reflect
#
# **What was hardest?**
# `YOUR ANSWER:`
#
# **What did you learn?**
# `YOUR ANSWER:`
#
# **Confidence 1-10:**
# `YOUR ANSWER:`
#
# **If stuck — what did you try first?**
# `YOUR ANSWER:`
