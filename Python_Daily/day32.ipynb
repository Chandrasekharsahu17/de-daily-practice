# %% [markdown]
# # Day 32 — Jul 09 2026 (Thursday)
# ## Topic: OOP Full Pipeline
#
# ---
# **Rule:** Attempt 15 min before Googling. Write what you tried even if wrong.

# %% [markdown]
# ## CONCEPT RECAP — Read this first
#
# > Run this example. Understand each line. Then close it and write your own code.

# %%
# ─── CONCEPT EXAMPLE ───────────────────────────────

from abc import ABC, abstractmethod

class Pipeline(ABC):
    @abstractmethod
    def extract(self): pass
    @abstractmethod
    def transform(self, df): pass
    @abstractmethod
    def load(self, df): pass

    def run(self):
        print(f'--- {self.__class__.__name__} ---')
        df = self.extract()
        df = self.transform(df)
        self.load(df)

class OrdersPipeline(Pipeline):
    def extract(self): return pd.read_csv('orders.csv')
    def transform(self, df): return df.dropna()
    def load(self, df): df.to_csv('clean.csv', index=False)

OrdersPipeline().run()

# %% [markdown]
# ---
# ## Q1
#
# > Build DataLake class: ingest(raw_data)->bronze/, clean()->silver/, aggregate()->gold/, status() prints row counts. Test full flow.

# %%
# YOUR CODE:
# Attempt before Googling
# If stuck: write what you tried and WHY it failed

# %% [markdown]
# ---
# ## Q2
#
# > Add @log_execution on all DataLake methods. Add @retry(3) on ingest(). Run pipeline, review log file.

# %%
# YOUR CODE:

# %% [markdown]
# ---
# ## Reflect
#
# **What was hardest?**
# `YOUR ANSWER:`
#
# **What did you learn?**
# `YOUR ANSWER:`
#
# **Confidence 1-10:**
# `YOUR ANSWER:`
#
# **If stuck — what did you try first?**
# `YOUR ANSWER:`
