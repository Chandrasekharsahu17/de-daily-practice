# %% [markdown]
# # Day 03 — Jun 03 2026 (Wednesday)
# ## Topic: List Comprehensions
#
# ---
# **Rule:** Attempt 15 min before Googling. Write what you tried even if wrong.

# %% [markdown]
# ## CONCEPT RECAP — Read this first
#
# > Run this example. Understand each line. Then close it and write your own code.

# %%
# ─── CONCEPT EXAMPLE ───────────────────────────────

# Formula: [expression  for item in list  if condition]

# Example 1: square numbers
squares = [x**2 for x in range(5)]  # [0,1,4,9,16]

# Example 2: filter + transform
prices = [100, 500, 15000, 25000]
gst = [p * 1.18 for p in prices if p > 10000]  # [17700.0, 29500.0]

# Example 3: transform dicts
products = [{'name':'Laptop','cat':'Electronics','price':75000},
            {'name':'Shirt','cat':'Clothing','price':1200}]
result = [{'name':p['name'],'gst_price':round(p['price']*1.18,2)}
          for p in products if p['cat']=='Electronics']

# %% [markdown]
# ---
# ## Q1
#
# > Rewrite as list comprehension:
# prices=[]
# for p in products:
#     if p['price']>10000:
#         prices.append(p['price']*1.18)
# products=[{'price':20000},{'price':388},{'price':25000}]
# Print prices (not products).

# %%
# YOUR CODE:
# Attempt before Googling
# If stuck: write what you tried and WHY it failed
products=[{'price':20000},{'price':388},{'price':25000}]
prices=[] 
# for p in products: 
#     if p['price']>10000: 
#         prices.append(p['price']*1.18)
# prices

a=[prices.append(i['price']*1.18) for i in products if i['price']>10000]
prices

# %% [markdown]
# ---
# ## Q2
#
# > Using list comprehension create: [{'name':X,'gst_price':Y}] from products list where only Electronics are included. gst_price = price * 1.18

# %%
# YOUR CODE:
products = [
    {"name": "Laptop", "category": "Electronics", "price": 50000},
    {"name": "Shirt", "category": "Clothing", "price": 1200},
    {"name": "Mobile", "category": "Electronics", "price": 25000},
    {"name": "Book", "category": "Education", "price": 500},
    {"name": "Headphones", "category": "Electronics", "price": 3000}
]
a=[{'name':i["name"],'gst_price':i["price"]*1.18}for i in products if i['category']=="Electronics"]
a

# %% [markdown]
# ---
# ## Reflect
#
# **What was hardest?**
# `YOUR ANSWER:`easy i wrote all code on my own
#
# **What did you learn?**
# `YOUR ANSWER:`comprenesion to core
#
# **Confidence 1-10:**
# `YOUR ANSWER:`9
#
# **If stuck — what did you try first?**
# `YOUR ANSWER:`n/a
