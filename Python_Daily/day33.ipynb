# %% [markdown]
# # Day 33 — Jul 10 2026 (Friday)
# ## Topic: Mixed Review
#
# ---
# **Rule:** Attempt 15 min before Googling. Write what you tried even if wrong.

# %% [markdown]
# ## CONCEPT RECAP — Read this first
#
# > Run this example. Understand each line. Then close it and write your own code.

# %%
# ─── CONCEPT EXAMPLE ───────────────────────────────

# Day 33 - Review Day
# Pick your 2 weakest topics. Redo those questions.
# No new concepts today.

# %% [markdown]
# ---
# ## Q1
#
# > Write your own question on your weakest topic. Solve it completely. Explain what was hard.

# %%
# YOUR CODE:
# Attempt before Googling
# If stuck: write what you tried and WHY it failed

# %% [markdown]
# ---
# ## Q2
#
# > Write a function reading nested JSON transactions, flattening to DataFrame, handling missing fields gracefully, adding total_value=sum(qty*price) per transaction.

# %%
# YOUR CODE:

# %% [markdown]
# ---
# ## Reflect
#
# **What was hardest?**
# `YOUR ANSWER:`
#
# **What did you learn?**
# `YOUR ANSWER:`
#
# **Confidence 1-10:**
# `YOUR ANSWER:`
#
# **If stuck — what did you try first?**
# `YOUR ANSWER:`
