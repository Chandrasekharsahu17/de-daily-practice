# %% [markdown]
# # Day 29 — Jul 06 2026 (Monday)
# ## Topic: ETL Project Part 1
#
# ---
# **Rule:** Attempt 15 min before Googling. Write what you tried even if wrong.

# %% [markdown]
# ## CONCEPT RECAP — Read this first
#
# > Run this example. Understand each line. Then close it and write your own code.

# %%
# ─── CONCEPT EXAMPLE ───────────────────────────────

import random, string
from datetime import date, timedelta

products = ['Laptop','Phone','Tablet','Watch','Earbuds']
statuses = ['completed','pending','cancelled']

# Generate realistic fake data
def random_date(year=2024):
    start = date(year,1,1)
    delta = timedelta(days=random.randint(0,364))
    return str(start + delta)

orders = [
    {'order_id': i,
     'customer': f'Customer_{random.randint(1,50)}',
     'product':  random.choice(products),
     'qty':      random.randint(1,5),
     'price':    random.randint(1000,100000),
     'date':     random_date(),
     'status':   random.choice(statuses)}
    for i in range(1, 501)
]

# %% [markdown]
# ---
# ## Q1
#
# > Generate 500 fake orders using the pattern above. Save to bronze/raw_orders.csv. Print: shape, dtypes, null counts, status distribution.

# %%
# YOUR CODE:
# Attempt before Googling
# If stuck: write what you tried and WHY it failed

# %% [markdown]
# ---
# ## Q2
#
# > Validate your bronze data:
# 1. No duplicate order_ids
# 2. qty between 1-10
# 3. price positive
# 4. date in 2024
# 5. status in allowed values
# Print: records passed, failed, failure details.

# %%
# YOUR CODE:

# %% [markdown]
# ---
# ## Reflect
#
# **What was hardest?**
# `YOUR ANSWER:`
#
# **What did you learn?**
# `YOUR ANSWER:`
#
# **Confidence 1-10:**
# `YOUR ANSWER:`
#
# **If stuck — what did you try first?**
# `YOUR ANSWER:`
