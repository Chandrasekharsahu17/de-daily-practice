# %% [markdown]
# # Day 45 — Jul 28 2026 (Tuesday)
# ## Topic: GRADUATION DAY
#
# ---
# **Rule:** Attempt 15 min before Googling. Write what you tried even if wrong.

# %% [markdown]
# ## CONCEPT RECAP — Read this first
#
# > Run this example. Understand each line. Then close it and write your own code.

# %%
# ─── CONCEPT EXAMPLE ───────────────────────────────

# Day 45 - you made it!
# Build your most complete pipeline:
# Raw messy data -> validate -> clean -> aggregate
# -> load to SQLite -> business report
# -> full logging -> one run() call

# %% [markdown]
# ---
# ## Q1
#
# > Build GRADUATION pipeline: ingest orders -> validate -> clean (Silver) -> aggregate (Gold) -> load SQLite -> print report (top 3 products, best month, revenue, data quality score). Full logging. Full error handling. One run().

# %%
# YOUR CODE:
# Attempt before Googling
# If stuck: write what you tried and WHY it failed

# %% [markdown]
# ---
# ## Q2
#
# > Write 2 hardest Python DE interview questions you can think of. Solve both. Then write: what are you most confident in? What still needs work? Be honest.

# %%
# YOUR CODE:

# %% [markdown]
# ---
# ## Reflect
#
# **What was hardest?**
# `YOUR ANSWER:`
#
# **What did you learn?**
# `YOUR ANSWER:`
#
# **Confidence 1-10:**
# `YOUR ANSWER:`
#
# **If stuck — what did you try first?**
# `YOUR ANSWER:`
