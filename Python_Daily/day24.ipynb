# %% [markdown]
# # Day 24 — Jun 29 2026 (Monday)
# ## Topic: Decorators
#
# ---
# **Rule:** Attempt 15 min before Googling. Write what you tried even if wrong.

# %% [markdown]
# ## CONCEPT RECAP — Read this first
#
# > Run this example. Understand each line. Then close it and write your own code.

# %%
# ─── CONCEPT EXAMPLE ───────────────────────────────

import time, functools

def log_execution(func):
    @functools.wraps(func)
    def wrapper(*args, **kwargs):
        print(f'Starting: {func.__name__}')
        start = time.time()
        result = func(*args, **kwargs)
        elapsed = time.time() - start
        print(f'Done: {func.__name__} ({elapsed:.3f}s)')
        return result
    return wrapper

@log_execution
def extract(filepath):
    return []

extract('data.csv')
# Starting: extract
# Done: extract (0.001s)

# %% [markdown]
# ---
# ## Q1
#
# > Write @log_execution decorator: logs function name, time taken. Apply to extract(), transform(), load(). Show log output.

# %%
# YOUR CODE:
# Attempt before Googling
# If stuck: write what you tried and WHY it failed

# %% [markdown]
# ---
# ## Q2
#
# > Write @retry(max_attempts=3, delay=1): retries on exception, logs each attempt. Test with function that fails randomly (random.random() < 0.7).

# %%
# YOUR CODE:

# %% [markdown]
# ---
# ## Reflect
#
# **What was hardest?**
# `YOUR ANSWER:`
#
# **What did you learn?**
# `YOUR ANSWER:`
#
# **Confidence 1-10:**
# `YOUR ANSWER:`
#
# **If stuck — what did you try first?**
# `YOUR ANSWER:`
