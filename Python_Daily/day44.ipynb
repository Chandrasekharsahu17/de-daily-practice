# %% [markdown]
# # Day 44 — Jul 27 2026 (Monday)
# ## Topic: Final Review
#
# ---
# **Rule:** Attempt 15 min before Googling. Write what you tried even if wrong.

# %% [markdown]
# ## CONCEPT RECAP — Read this first
#
# > Run this example. Understand each line. Then close it and write your own code.

# %%
# ─── CONCEPT EXAMPLE ───────────────────────────────

# Day 44 - review before graduation
# Key patterns:
# ETL: extract->validate->transform->load
# OOP: class with all pipeline steps
# Errors: never crash silently
# Memory: generators for large data
# Speed: vectorized > apply > loop

# %% [markdown]
# ---
# ## Q1
#
# > Pick weakest concept from days 1-43. Write 2 questions yourself. Solve both without looking at notes.

# %%
# YOUR CODE:
# Attempt before Googling
# If stuck: write what you tried and WHY it failed

# %% [markdown]
# ---
# ## Q2
#
# > Write DataEngineerToolkit class: validator, cleaner, aggregator, loader all in one. Test with employee and orders data.

# %%
# YOUR CODE:

# %% [markdown]
# ---
# ## Reflect
#
# **What was hardest?**
# `YOUR ANSWER:`
#
# **What did you learn?**
# `YOUR ANSWER:`
#
# **Confidence 1-10:**
# `YOUR ANSWER:`
#
# **If stuck — what did you try first?**
# `YOUR ANSWER:`
