# %% [markdown]
# # Day 22 — Jun 25 2026 (Thursday)
# ## Topic: Logging
#
# ---
# **Rule:** Attempt 15 min before Googling. Write what you tried even if wrong.

# %% [markdown]
# ## CONCEPT RECAP — Read this first
#
# > Run this example. Understand each line. Then close it and write your own code.

# %%
# ─── CONCEPT EXAMPLE ───────────────────────────────

import logging

logging.basicConfig(
    level=logging.DEBUG,
    format='%(asctime)s | %(levelname)s | %(message)s',
    handlers=[
        logging.FileHandler('pipeline.log'),
        logging.StreamHandler()
    ]
)

logging.debug('Detailed debug info')
logging.info('Pipeline started')
logging.warning('30% rows dropped')
logging.error('File not found')
logging.critical('Database crashed')

# Log exception with full traceback
try:
    1/0
except Exception as e:
    logging.error('Failed', exc_info=True)

# %% [markdown]
# ---
# ## Q1
#
# > Add logging to an ETL pipeline: log start time, rows before/after each step, any errors with exc_info=True. Review the log file output.

# %%
# YOUR CODE:
# Attempt before Googling
# If stuck: write what you tried and WHY it failed

# %% [markdown]
# ---
# ## Q2
#
# > Create 3 named loggers: etl_logger -> etl.log, db_logger -> db.log, error_logger -> errors.log (ERROR only). Write realistic messages in a pipeline simulation.

# %%
# YOUR CODE:

# %% [markdown]
# ---
# ## Reflect
#
# **What was hardest?**
# `YOUR ANSWER:`
#
# **What did you learn?**
# `YOUR ANSWER:`
#
# **Confidence 1-10:**
# `YOUR ANSWER:`
#
# **If stuck — what did you try first?**
# `YOUR ANSWER:`
