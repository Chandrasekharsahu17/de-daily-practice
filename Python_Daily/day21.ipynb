# %% [markdown]
# # Day 21 — Jun 24 2026 (Wednesday)
# ## Topic: SQLite with Python
#
# ---
# **Rule:** Attempt 15 min before Googling. Write what you tried even if wrong.

# %% [markdown]
# ## CONCEPT RECAP — Read this first
#
# > Run this example. Understand each line. Then close it and write your own code.

# %%
# ─── CONCEPT EXAMPLE ───────────────────────────────

import sqlite3, pandas as pd

conn = sqlite3.connect('company.db')
cursor = conn.cursor()

cursor.execute('''
    CREATE TABLE IF NOT EXISTS orders
    (id INTEGER PRIMARY KEY, customer TEXT, amount REAL, status TEXT)
''')

data = [(1,'Raj',5000,'completed'),(2,'Priya',3000,'pending')]
cursor.executemany('INSERT INTO orders VALUES (?,?,?,?)', data)
conn.commit()

# Query
cursor.execute('SELECT * FROM orders WHERE amount > 2000')
rows = cursor.fetchall()

# With Pandas
df = pd.read_sql('SELECT * FROM orders', conn)
conn.close()

# %% [markdown]
# ---
# ## Q1
#
# > Create SQLite 'orders.db' with orders table. Insert 10 orders using executemany(). Query: top 3 by amount, count by status, avg amount.

# %%
# YOUR CODE:
# Attempt before Googling
# If stuck: write what you tried and WHY it failed

# %% [markdown]
# ---
# ## Q2
#
# > Pipeline: read employee CSV -> validate -> insert to SQLite via to_sql() -> query back with pd.read_sql() -> print summary stats by dept.

# %%
# YOUR CODE:

# %% [markdown]
# ---
# ## Reflect
#
# **What was hardest?**
# `YOUR ANSWER:`
#
# **What did you learn?**
# `YOUR ANSWER:`
#
# **Confidence 1-10:**
# `YOUR ANSWER:`
#
# **If stuck — what did you try first?**
# `YOUR ANSWER:`
