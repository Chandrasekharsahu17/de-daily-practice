# %% [markdown]
# # Day 06 — Jun 06 2026 (Saturday)
# ## Topic: File Operations
#
# ---
# **Rule:** Attempt 15 min before Googling. Write what you tried even if wrong.

# %% [markdown]
# ## CONCEPT RECAP — Read this first
#
# > Run this example. Understand each line. Then close it and write your own code.

# %%
# ─── CONCEPT EXAMPLE ───────────────────────────────

import csv, json

# Write CSV
with open('data.csv','w',newline='') as f:
    writer = csv.DictWriter(f, fieldnames=['id','name'])
    writer.writeheader()
    writer.writerows([{'id':1,'name':'Raj'}])

# Read CSV - returns list of dicts
with open('data.csv') as f:
    rows = list(csv.DictReader(f))

# JSON
data = [{'id':1,'name':'Raj'}]
with open('data.json','w') as f:
    json.dump(data, f, indent=2)

with open('data.json') as f:
    data = json.load(f)

# ALWAYS use 'with' - auto closes file

# %% [markdown]
# ---
# ## Q1
#
# > Write write_and_read(data, filename): saves list of dicts to filename.csv AND filename.json, reads both back, prints row count before and after.

# %%
# YOUR CODE:
# Attempt before Googling
# If stuck: write what you tried and WHY it failed

# %% [markdown]
# ---
# ## Q2
#
# > Write read_csv_safe(filepath) that handles FileNotFoundError and empty file. Always returns list of dicts or empty list. Never crashes.

# %%
# YOUR CODE:
def read_csv_safe(filepath):
    try:
      with open(filepath,"r") as f:
            c=f.read()
            return c
    except FileNotFoundError:
        print("file not found")
        return[]
    else :
        return[]
    finally:
        return []

# %% [markdown]
# ---
# ## Reflect
#
# **What was hardest?**
# `YOUR ANSWER:`i cant do all these csv and json how to read and write what does each line mean i dont know all these
#
# **What did you learn?**
# `YOUR ANSWER:`nothing i cant even understand
#
# **Confidence 1-10:**
# `YOUR ANSWER:`2
#
# **If stuck — what did you try first?**
# `YOUR ANSWER:`i only know with open("files.txt","w/r/x/r+") as f:
# and little more i dont know with read and write with csv and json
