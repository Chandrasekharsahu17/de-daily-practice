# %% [markdown]
# # Day 08 — Jun 09 2026 (Tuesday)
# ## Topic: String Operations
#
# ---
# **Rule:** Attempt 15 min before Googling. Write what you tried even if wrong.

# %% [markdown]
# ## CONCEPT RECAP — Read this first
#
# > Run this example. Understand each line. Then close it and write your own code.

# %%
# ─── CONCEPT EXAMPLE ───────────────────────────────

name = '  RAJ SHARMA  '
clean = name.strip().title()   # 'Raj Sharma'

# Common string methods
'hello'.upper()           # 'HELLO'
'HELLO'.lower()           # 'hello'
'hello world'.split(' ')  # ['hello','world']
'raj@gmail.com'.split('@')[0]  # 'raj'
'raj@gmail.com'.split('@')[1]  # 'gmail.com'

# Check contains
'ERROR' in 'ERROR: timeout'  # True

# f-string formatting
name='raj'; salary=85000
print(f'{name.title()} earns {salary:,}')  # Raj earns 85,000

# Clean a list of names
names = ['  RAJ  ','priya ','AMIT']
clean = [n.strip().title() for n in names]

# %% [markdown]
# ---
# ## Q1
#
# > Given messy_names = ['  RAJ SHARMA  ','priya mehta','AMIT  KUMAR','  sneha patel  '], clean all (strip+title), split into first and last name. Return list of dicts: [{'full':'Raj Sharma','first':'Raj','last':'Sharma'}]

# %%
# YOUR CODE:
# Attempt before Googling
# If stuck: write what you tried and WHY it failed

# %% [markdown]
# ---
# ## Q2
#
# > Parse emails = ['Raj.Sharma@Gmail.COM','  PRIYA@yahoo.com  ','invalid-email','sneha@company.in']. For each: strip, lowercase, extract username and domain. Flag ones without @ as invalid.

# %%
# YOUR CODE:

# %% [markdown]
# ---
# ## Reflect
#
# **What was hardest?**
# `YOUR ANSWER:`
#
# **What did you learn?**
# `YOUR ANSWER:`
#
# **Confidence 1-10:**
# `YOUR ANSWER:`
#
# **If stuck — what did you try first?**
# `YOUR ANSWER:`
