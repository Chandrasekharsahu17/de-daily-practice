# %% [markdown]
# # Day 37 — Jul 16 2026 (Thursday)
# ## Topic: Full Stack Challenge 1
#
# ---
# **Rule:** Attempt 15 min before Googling. Write what you tried even if wrong.

# %% [markdown]
# ## CONCEPT RECAP — Read this first
#
# > Run this example. Understand each line. Then close it and write your own code.

# %%
# ─── CONCEPT EXAMPLE ───────────────────────────────

# Bronze -> Silver -> Gold -> SQLite -> Report
# All in one pipeline with logging and error handling

# %% [markdown]
# ---
# ## Q1
#
# > Build complete pipeline: ingest 500 orders, validate, clean (Silver), aggregate 3 metrics (Gold), load to SQLite, print business report. Full logging. One run() call.

# %%
# YOUR CODE:
# Attempt before Googling
# If stuck: write what you tried and WHY it failed

# %% [markdown]
# ---
# ## Q2
#
# > Add monitoring: check row count didn't drop >20% between layers. If >50% drop: CRITICAL halt. Generate pipeline_health_report at end.

# %%
# YOUR CODE:

# %% [markdown]
# ---
# ## Reflect
#
# **What was hardest?**
# `YOUR ANSWER:`
#
# **What did you learn?**
# `YOUR ANSWER:`
#
# **Confidence 1-10:**
# `YOUR ANSWER:`
#
# **If stuck — what did you try first?**
# `YOUR ANSWER:`
