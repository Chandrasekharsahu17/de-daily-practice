# %% [markdown]
# # Day 19 — Jun 22 2026 (Monday)
# ## Topic: Multiple File Formats
#
# ---
# **Rule:** Attempt 15 min before Googling. Write what you tried even if wrong.

# %% [markdown]
# ## CONCEPT RECAP — Read this first
#
# > Run this example. Understand each line. Then close it and write your own code.

# %%
# ─── CONCEPT EXAMPLE ───────────────────────────────

import pandas as pd, json

# CSV
df.to_csv('out.csv', index=False)  # no row numbers!
df = pd.read_csv('out.csv', na_values=['NA','N/A','null',''])

# JSON
df.to_json('out.json', orient='records', indent=2)
df = pd.read_json('out.json', orient='records')

# Dates may not preserve correctly across formats
# Always verify dtypes after reading
print(df.dtypes)

# %% [markdown]
# ---
# ## Q1
#
# > Write data_reader(source_type, source): handles 'csv','json','dict_list'.
# Always return (df, metadata) where metadata={'rows':N,'cols':N,'nulls':N}.

# %%
# YOUR CODE:
# Attempt before Googling
# If stuck: write what you tried and WHY it failed

# %% [markdown]
# ---
# ## Q2
#
# > Save employee data to both CSV and JSON. Read both back. Compare dtypes. Are dates preserved? Write findings as comments.

# %%
# YOUR CODE:

# %% [markdown]
# ---
# ## Reflect
#
# **What was hardest?**
# `YOUR ANSWER:`
#
# **What did you learn?**
# `YOUR ANSWER:`
#
# **Confidence 1-10:**
# `YOUR ANSWER:`
#
# **If stuck — what did you try first?**
# `YOUR ANSWER:`
