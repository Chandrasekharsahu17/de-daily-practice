# %% [markdown]
# # Day 38 — Jul 17 2026 (Friday)
# ## Topic: Full Stack Challenge 2
#
# ---
# **Rule:** Attempt 15 min before Googling. Write what you tried even if wrong.

# %% [markdown]
# ## CONCEPT RECAP — Read this first
#
# > Run this example. Understand each line. Then close it and write your own code.

# %%
# ─── CONCEPT EXAMPLE ───────────────────────────────

# Multi-source merge + change detection
# Common in real DE: track what changed day over day

# %% [markdown]
# ---
# ## Q1
#
# > Merge 3 systems (HR, Payroll, Access) into unified employee profile. Add completeness_score = % of fields filled per employee.

# %%
# YOUR CODE:
# Attempt before Googling
# If stuck: write what you tried and WHY it failed

# %% [markdown]
# ---
# ## Q2
#
# > Build data drift detector: given yesterday_df and today_df, find new/deleted/modified records. Output change_report with counts and changed fields.

# %%
# YOUR CODE:

# %% [markdown]
# ---
# ## Reflect
#
# **What was hardest?**
# `YOUR ANSWER:`
#
# **What did you learn?**
# `YOUR ANSWER:`
#
# **Confidence 1-10:**
# `YOUR ANSWER:`
#
# **If stuck — what did you try first?**
# `YOUR ANSWER:`
