# %% [markdown]
# # 🐍 Day 29 — Jul 06 2026 (Monday)
# ## Python Topic: Performance Optimization
# **Time:** 20 minutes
#
# ---

# %%
# ─────────────────────────────────────────
# PYTHON Q1
# Compare 3 ways to add 18% GST to 1M prices: for loop, apply(), vectorized (df*1.18). Time all 3. Print results.
# ─────────────────────────────────────────

# YOUR CODE:

# %%
# ─────────────────────────────────────────
# PYTHON Q2
# Find memory usage before and after: drop unused columns, convert object to category, downcast integers. Show % reduction.
# ─────────────────────────────────────────

# YOUR CODE:

# %% [markdown]
# ## Reflect
# **What was hardest today?**
# `YOUR ANSWER:`
#
# **What did you learn that you did not know before?**
# `YOUR ANSWER:`
#
# **Confidence level 1-10:**
# `YOUR ANSWER:`
