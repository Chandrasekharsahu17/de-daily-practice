# %% [markdown]
# # 🐍 Day 24 — Jun 29 2026 (Monday)
# ## Python Topic: Generators
# **Time:** 20 minutes
#
# ---

# %%
# ─────────────────────────────────────────
# PYTHON Q1
# Write read_large_csv(filepath, chunk_size) generator that yields chunks of rows. Process 1M rows without loading all into memory.
# ─────────────────────────────────────────

# YOUR CODE:

# %%
# ─────────────────────────────────────────
# PYTHON Q2
# Write a generator that yields batches of records for database insertion. Show memory usage difference vs loading all at once.
# ─────────────────────────────────────────

# YOUR CODE:

# %% [markdown]
# ## Reflect
# **What was hardest today?**
# `YOUR ANSWER:`
#
# **What did you learn that you did not know before?**
# `YOUR ANSWER:`
#
# **Confidence level 1-10:**
# `YOUR ANSWER:`
