# %% [markdown]
# # 🐍 Day 23 — Jun 26 2026 (Friday)
# ## Python Topic: Decorators
# **Time:** 20 minutes
#
# ---

# %%
# ─────────────────────────────────────────
# PYTHON Q1
# Write @log_execution decorator: logs function name, start time, end time, duration. Apply to all ETL functions.
# ─────────────────────────────────────────

# YOUR CODE:

# %%
# ─────────────────────────────────────────
# PYTHON Q2
# Write @retry(max_attempts=3, delay=1) decorator that retries a function on exception. Test with a function that fails randomly.
# ─────────────────────────────────────────

# YOUR CODE:

# %% [markdown]
# ## Reflect
# **What was hardest today?**
# `YOUR ANSWER:`
#
# **What did you learn that you did not know before?**
# `YOUR ANSWER:`
#
# **Confidence level 1-10:**
# `YOUR ANSWER:`
