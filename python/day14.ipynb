# %% [markdown]
# # 🐍 Day 14 — Jun 16 2026 (Tuesday)
# ## Python Topic: Pandas merge join
# **Time:** 20 minutes
#
# ---

# %%
# ─────────────────────────────────────────
# PYTHON Q1
# Merge orders with customers. Left join. Find orders where customer info is missing. How many orphan orders?
# ─────────────────────────────────────────

# YOUR CODE:

# %%
# ─────────────────────────────────────────
# PYTHON Q2
# Merge order_items with products. Calculate revenue (qty*unit_price) per product. Find top 3 products by total revenue.
# ─────────────────────────────────────────

# YOUR CODE:

# %% [markdown]
# ## Reflect
# **What was hardest today?**
# `YOUR ANSWER:`
#
# **What did you learn that you did not know before?**
# `YOUR ANSWER:`
#
# **Confidence level 1-10:**
# `YOUR ANSWER:`
