# %% [markdown]
# # 🐍 Day 03 — Jun 03 2026 (Wednesday)
# ## Python Topic: List Comprehensions
# **Time:** 20 minutes
#
# ---

# %%
# ─────────────────────────────────────────
# PYTHON Q1
# Rewrite this loop as a list comprehension: prices=[]; for p in products: if p['price']>10000: prices.append(p['price']*1.18)
# ─────────────────────────────────────────

# YOUR CODE:
products = [
    {"price": 20000},
    {"price": 2838838},
    {"price": 388},
    {"price": 2929}
]

prices = [p['price'] * 1.18 for p in products if p['price'] > 10000]

print(products)

# %%
# ─────────────────────────────────────────
# PYTHON Q2
# Using a list comprehension create a list of dicts: [{name: X, gst_price: Y}] from a products list where only Electronics are included.
# ─────────────────────────────────────────

# YOUR CODE:
products = [
    {"name": "Laptop", "category": "Electronics", "price": 50000},
    {"name": "Mouse", "category": "Electronics", "price": 800},
    {"name": "Shirt", "category": "Clothing", "price": 1200},
    {"name": "Mobile", "category": "Electronics", "price": 25000},
    {"name": "Book", "category": "Stationery", "price": 500},
    {"name": "Headphones", "category": "Electronics", "price": 3000}
]

b={}
a=[{i['name']:i['price']}for i in products if i['category']== 'Electronics' ]
a

# %% [markdown]
# ## Reflect
# **What was hardest today?**
# `YOUR ANSWER:`i should know the input value or else it beacmae difficult o know the question
#
# **What did you learn that you did not know before?**
# `YOUR ANSWER:`
# i forgot the syntax but now i got this
# **Confidence level 1-10:**
# `YOUR ANSWER:`6
