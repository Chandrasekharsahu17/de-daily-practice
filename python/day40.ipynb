# %% [markdown]
# # 🐍 Day 40 — Jul 21 2026 (Tuesday)
# ## Python Topic: Data Quality Framework
# **Time:** 20 minutes
#
# ---

# %%
# ─────────────────────────────────────────
# PYTHON Q1
# Build DataQualityFramework class: register rules, run all rules, generate HTML-like text report with pass/fail per rule.
# ─────────────────────────────────────────

# YOUR CODE:

# %%
# ─────────────────────────────────────────
# PYTHON Q2
# Add severity levels to rules: CRITICAL (halt), WARNING (continue), INFO (log only). Run framework on your mini project data.
# ─────────────────────────────────────────

# YOUR CODE:

# %% [markdown]
# ## Reflect
# **What was hardest today?**
# `YOUR ANSWER:`
#
# **What did you learn that you did not know before?**
# `YOUR ANSWER:`
#
# **Confidence level 1-10:**
# `YOUR ANSWER:`
