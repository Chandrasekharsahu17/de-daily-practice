# %% [markdown]
# # 🐍 Day 12 — Jun 13 2026 (Saturday)
# ## Python Topic: Pandas Cleaning
# **Time:** 20 minutes
#
# ---

# %%
# ─────────────────────────────────────────
# PYTHON Q1
# Given a messy DataFrame with nulls, duplicates, negative ages, wrong dtypes — clean it completely step by step.
# ─────────────────────────────────────────

# YOUR CODE:

# %%
# ─────────────────────────────────────────
# PYTHON Q2
# Write clean_dataframe(df, config) where config specifies: fill_cols (fill with median), drop_cols (drop if null), validate_range {col: (min,max)}.
# ─────────────────────────────────────────

# YOUR CODE:

# %% [markdown]
# ## Reflect
# **What was hardest today?**
# `YOUR ANSWER:`
#
# **What did you learn that you did not know before?**
# `YOUR ANSWER:`
#
# **Confidence level 1-10:**
# `YOUR ANSWER:`
